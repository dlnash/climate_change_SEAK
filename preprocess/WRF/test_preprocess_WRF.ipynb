# %%
import os
import sys
import glob
import yaml
import xarray as xr

# Path to custom modules
sys.path.append('../../modules')
import globalvars
import wrf_preprocess as wrf_prep
# Out:
# /home/dnash/miniconda3/envs/SEAK-impacts/lib/python3.12/site-packages/wrf/__init__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
year = 2013
output_varname = 'freezing_level'
model = 'cfsr'

# %%
# --- Define paths ---
path_to_data = globalvars.path_to_data
path_to_wrf = os.path.join(path_to_data, f"downloads/SEAK-WRF/{model}/")
path_to_out = os.path.join(path_to_data, f"preprocessed/SEAK-WRF/{model}/{output_varname}/")
os.makedirs(path_to_out, exist_ok=True)

# %%
filenames = sorted(glob.glob(os.path.join(path_to_wrf, f"WRFDS_{year}*")))
print(filenames[0])
# Out:
# /cw3e/mead/projects/cwp140/data/downloads/SEAK-WRF/cfsr/WRFDS_2013-01-01.nc

# %%
ds = xr.open_dataset(filenames[0])
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:        (south_north: 250, west_east: 320, Time: 1,
#                     interp_levels: 9, soil_layers_stag: 4)
# Coordinates:
#     XLAT           (south_north, west_east) float32 320kB ...
#     XLONG          (south_north, west_east) float32 320kB ...
#   * Time           (Time) datetime64[ns] 8B 2013-01-01
#   * interp_levels  (interp_levels) float32 36B 100.0 200.0 300.0 ... 925.0 1e+03
# Dimensions without coordinates: south_north, west_east, soil_layers_stag
# Data variables: (12/37)
#     lat            (south_north, west_east) float32 320kB ...
#     lon            (south_north, west_east) float32 320kB ...
#     SLP            (Time, south_north, west_east) float32 320kB ...
#     PSFC           (Time, south_north, west_east) float32 320kB ...
#     U10            (Time, south_north, west_east) float32 320kB ...
#     V10            (Time, south_north, west_east) float32 320kB ...
#     ...             ...
# ...

# %%
ds1 = wrf_prep.preprocess_WRF_freezing_level(ds, filenames[0])
ds2 = wrf_prep.preprocess_WRF_freezing_level(ds, filenames[1])

# %%
ds1
# Out:
# <xarray.Dataset> Size: 960kB
# Dimensions:         (Time: 1, south_north: 250, west_east: 320)
# Coordinates:
#     lat             (south_north, west_east) float32 320kB 53.12 53.12 ... 61.95
#     lon             (south_north, west_east) float32 320kB -148.1 ... -126.3
#   * Time            (Time) datetime64[ns] 8B 2013-01-01
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     freezing_level  (Time, south_north, west_east) float32 320kB 500.8 ... nan
# Attributes:
#     contact:  rtladerjr@alaska.edu
#     info:     Alaska CASC
#     data:     Downscaled CFSR
#     format:   version 2
#     date:     Tue Jun 11 16:14:45 AKDT 2019

# %%
new_ds = xr.concat([ds1, ds2], dim="Time")
new_ds
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:         (Time: 2, south_north: 250, west_east: 320)
# Coordinates:
#     lat             (south_north, west_east) float32 320kB 53.12 53.12 ... 61.95
#     lon             (south_north, west_east) float32 320kB -148.1 ... -126.3
#   * Time            (Time) datetime64[ns] 16B 2013-01-01 2013-01-02
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     freezing_level  (Time, south_north, west_east) float32 640kB 500.8 ... nan
# Attributes:
#     contact:  rtladerjr@alaska.edu
#     info:     Alaska CASC
#     data:     Downscaled CFSR
#     format:   version 2
#     date:     Tue Jun 11 16:14:45 AKDT 2019

# %%
ivt = wrf_prep.preprocess_WRF_ivt(ds, filenames[0])
ivt
# Out:
# Masking values below surface ....
# <xarray.Dataset> Size: 2MB
# Dimensions:  (Time: 1, south_north: 250, west_east: 320)
# Coordinates:
#   * Time     (Time) datetime64[ns] 8B 1980-01-01
#     lat      (south_north, west_east) float32 320kB 53.12 53.12 ... 61.96 61.95
#     lon      (south_north, west_east) float32 320kB -148.1 -148.0 ... -126.3
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     ivtu     (Time, south_north, west_east) float32 320kB -37.26 ... 38.75
#     ivtv     (Time, south_north, west_east) float32 320kB -22.51 ... 28.04
#     ivt      (Time, south_north, west_east) float32 320kB 43.53 43.54 ... 47.83

# %%
uv = wrf_prep.preprocess_WRF_uv(ds, filenames[0])
uv
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:        (Time: 1, south_north: 250, west_east: 320)
# Coordinates:
#     isobaricInhPa  float32 4B 850.0
#     lat            (south_north, west_east) float32 320kB 53.12 53.12 ... 61.95
#     lon            (south_north, west_east) float32 320kB -148.1 ... -126.3
#   * Time           (Time) datetime64[ns] 8B 1980-01-01
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     u              (Time, south_north, west_east) float32 320kB ...
#     v              (Time, south_north, west_east) float32 320kB ...
# Attributes:
#     contact:  rtladerjr@alaska.edu
#     info:     Alaska CASC
#     data:     Downscaled CFSR
#     format:   version 1
#     date:     Tue Dec 11 10:35:26 AKST 2018

# %%
pcpt = wrf_prep.preprocess_WRF_pcpt(ds, filenames[0])
pcpt
# Out:
# <xarray.Dataset> Size: 960kB
# Dimensions:  (Time: 1, south_north: 250, west_east: 320)
# Coordinates:
#     lat      (south_north, west_east) float32 320kB 53.12 53.12 ... 61.96 61.95
#     lon      (south_north, west_east) float32 320kB -148.1 -148.0 ... -126.3
#   * Time     (Time) datetime64[ns] 8B 1980-01-01
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     pcpt     (Time, south_north, west_east) float32 320kB ...
# Attributes:
#     contact:  rtladerjr@alaska.edu
#     info:     Alaska CASC
#     data:     Downscaled CFSR
#     format:   version 1
#     date:     Tue Dec 11 10:35:26 AKST 2018
