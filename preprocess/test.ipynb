# %%
import pandas as pd

# Read the file
df = pd.read_excel("../out/darrow_AK_landslide_inventory.xlsx", header=None)

# Rename columns from the two header rows
df.columns = [
    "Date",
    "Location",
    "Latitude",
    "Region",
    "Cause",
    "Injuries_Fatalities",
    "Damage_Impact",
    "Source",
]

# Remove the two header rows
df = df.iloc[2:].reset_index(drop=True)

records = []

# Every record occupies two rows
for i in range(0, len(df), 2):

    row1 = df.iloc[i]
    row2 = df.iloc[i + 1]
    records.append({
            "Date": pd.to_datetime(str(row1["Date"]).rstrip(","), errors="coerce"),
            "Julian_DOY": pd.to_numeric(row2["Date"], errors="coerce"),
            "Location": row1["Location"],
            "Latitude": pd.to_numeric(str(row1["Latitude"]).rstrip(","), errors="coerce"),
            "Longitude": pd.to_numeric(row2["Latitude"], errors="coerce"),
            "Region": row1["Region"],
            "Cause": row1["Cause"],
            "Injuries_Fatalities": row1["Injuries_Fatalities"],
            "Damage_Impact": row1["Damage_Impact"],
            "Source": row1["Source"],
})

new_df = pd.DataFrame(records)

new_df["Date"] = pd.to_datetime(new_df["Date"])

new_df
# Out:
#           Date  Julian_DOY                   Location  Latitude  Longitude  \
# 0   1883-10-06       279.0  Mt. St. Augustine Volcano  59.38548 -153.40216
# 1   1906-08-19       231.0         Sawtooth Mountains  65.36275 -149.57495
# 2   1912-08-10       222.0                       Ruby  64.73907 -155.49046
# 3   1912-10-04       277.0               Copper River  61.43704 -144.45007
# 4   1913-08-27       239.0                     Juneau  58.30580 -134.43330
# ..         ...         ...                        ...       ...        ...
# 276 2024-10-11       284.0                      Homer  59.67294 -151.69981
# 277 2024-10-12       285.0                     Haines  59.28123 -135.46534
# 278 2024-12-01       335.0                  Ketchikan  55.35912 -131.69321
# 279 2024-12-09       343.0                     Kodiak  57.73757 -152.51347
# 280 2025-01-12        12.0                     Seward  60.09340 -149.44457
#
#     Region Cause Injuries_Fatalities  \
# 0      NWG    VE                 ---
# 1      CIN   U/O                 ---
# 2      CIN     R                 ---
# 3     SEIN     R                 ---
# 4      CPH     R                 ---
# ..     ...   ...                 ...
# 276     CI     R                 ---
# 277    NPH     R                 ---
# 278    SPH     R                 ---
# 279    NWG     R                 ---
# 280    NWG   F/T                 ---
#
#                                  Damage_Impact            Source
# 0    LS caused tsunami that damaged structures  FDNM, 2007/02/04
# 1               Witnessed by a lone individual   FEN, 1906/08/25
# 2        Impacted a cabin with a person inside  FDNM, 1912/08/15
# 3                 Blocked CRNW railroad tracks  FDNM, 1912/10/15
# 4                              Damaged a flume  JADE, 1913/08/29
# ..                                         ...               ...
# 276                 Closed Diamond Creek Trail    HN, 2024/10/24
# 277                         Blocked Lutak Road   CVN, 2024/10/17
# 278               Damaged residential property   KDN, 2024/12/04
# 279                       Blocked Reznof Drive   KDM, 2024/12/10
# 280                  Blocked Lowell Point Road   APM, 2025/01/12
#
# [281 rows x 10 columns]

# %%
# Define filter criteria
start_date = pd.Timestamp("1981-01-01")
end_date   = pd.Timestamp("2019-12-31")

filtered_df = new_df[
    # Date range
    (new_df["Date"] >= start_date) &
# 167 2015-11-29       333.0                     Haines  59.28128 -135.46546
# 168 2015-11-30       334.0                     Haines  59.28772 -135.48928
# 169 2016-06-24       175.0    Haines Highway, Mile 20  59.38540 -135.84894
# 175 2017-05-21       141.0                     Haines  59.29447 -135.50617
# 176 2017-08-26       238.0                    Skagway  59.44709 -135.32144
# 177 2017-09-05       248.0                    Skagway  59.44709 -135.32144
# 179 2017-09-04       247.0                      Sitka  57.05320 -135.33460
# 180 2017-10-27       300.0                     Juneau  58.26946 -134.34384
# 181 2017-10-27       300.0                     Juneau  58.30486 -134.41747
# 189 2018-09-11       254.0    Haines Highway, Mile 19  59.37219 -135.83338
# 190 2018-09-11       254.0   Haines, Highway, Mile 20  59.38540 -135.84894
# 191 2018-10-05       278.0                     Haines  59.29447 -135.50617
# 193 2018-10-14       287.0    Haines Highway, Mile 23  59.23583 -135.44501
# 197 2019-01-01         1.0                 Thorne Bay  55.63116 -132.51710
# 201 2019-09-21       264.0                 Petersburg  56.61123 -132.79937
# 202 2019-10-06       279.0                     Juneau  58.26946 -134.34384
#
#     Region Cause  Injuries_Fatalities  \
# 51     NEG     R                  ---
# 60     CPH     R                  ---
# 61     NEG     R                0 / 1
# 64     NEG     R                  ---
# 67     SPH     R                  ---
# 68     NEG     R                  ---
# 70     CPH     R                0 / 1
# 81     CPH     R                  ---
# 82     NEG     R                  ---
# 83     NPH     R                  ---
# 84     CPH     R                  ---
# 85     NEG     R                  ---
# 86     CPH     R                  ---
# 87     NPH     R                  ---
# 90     NEG     R                  ---
# 91     NEG     R                  ---
# 96     NEG     R                  ---
# 102    SPH     R                  ---
# 105    CPH     R                  ---
# 106    CPH     R                  ---
# 107    NEG     R                  ---
# 108    CPH     R                  ---
# 114    CPH     R                  ---
# 120    CPH     R                  ---
# 123    SPH     R                  ---
# 124    SPH     R                  ---
# 126    SPH     R                  ---
# 128    SPH     R                  ---
# 129    NPH     R                  ---
# 130    NEG     R                  ---
# 131    NPH    R*                  ---
# 132    NPH    R*                  ---
# 145    SPH     R                  ---
# 146    SPH     R                  ---
# 147    NEG     R                  ---
# 155    SPH     R                  ---
# 156    NEG     R                  ---
# 157    SPH     R                  ---
# 158    SPH    R*                  ---
# 164    NEG     R  2000-03-01 00:00:00
# 166    CPH     R                  ---
# 167    NPH     R                  ---
# 168    NPH     R                  ---
# 169    NPH     R                  ---
# 175    NPH     R                  ---
# 176    NPH     R                  ---
# 177    NPH     R                  ---
# 179    NEG    R*                  ---
# 180    CPH     R                  ---
# 181    CPH     R                  ---
# 189    NPH     R                  ---
# 190    NPH     R                  ---
# 191    NPH     R                  ---
# 193    NPH     R                  ---
# 197    SPH     R                  ---
# 201    SPH     R                  ---
# 202    CPH     R                  ---
#
#                                          Damage_Impact            Source
# 51                          Blocked Sawmill Creek Road   DSS, 1981/01/12
# 60               Blocked Thane Road, damaged one house    JE, 1986/10/16
# 61                                 Destroyed one house   DSS, 1986/12/16
# 64                                Blocked city streets   DSS, 1989/01/25
# 67                         LS reported, damage unknown   ADN, 1989/10/31
# 68         Disrupted power, blocked Halibut Point Road   DSS, 1990/09/24
# 70                                 Destroyed one house   DSS, 1991/09/12
# 81                                     Disrupted power   DSS, 1996/07/15
# 82                                   Damaged one house   ADN, 1996/09/27
# 83                        Blocked the Klondike Highway   ADN, 1996/09/27
# 84              Damaged houses, blocked Calhoun Avenue   ADN, 1996/09/27
# 85                        Blocked Harbor Mountain Road   DSS, 1998/10/20
# 86                                       Damaged truck   DSS, 1998/10/21
# 87                                Damaged trailer park   DSS, 1998/12/02
# 90                          Blocked Halibut Point Road   DSS, 2020/10/06
# 91                          Blocked Halibut Point Road   DSS, 2000/10/11
# 96                                     Disrupted power   DSS, 2002/08/13
# 102  Damaged one house, blocked roads, disrupted power   DSS, 2003/10/30
# 105                                  Damaged one house   ADN, 2005/11/23
# 106                                       Blocked road   ADN, 2005/11/21
# 107                             Damaged city buildings   DSS, 2005/11/25
# 108                        Blocked Old Glacier Highway   ADN, 2005/11/23
# 114                 Blocked trail, witnessed by hikers   ADN, 2007/07/27
# 120                                  Damaged apartment   ADN, 2009/11/16
# 123            Blocked Eichner Avenue, disrupted power   KDN, 2011/08/17
# 124                              Destroyed parking lot   APM, 2011/08/24
# 126                        Blocked Deer Mountain Trail   KDN, 2011/09/13
# 128                              Closed Mitkof Highway   APM, 2011/09/23
# 129                                 Blocked Lutak Road   CVN, 2011/11/10
# 130                                 Damaged two houses  FDNM, 2011/12/02
# 131                                 Blocked Lutak Road   CVN, 2012/09/15
# 132                             Blocked Haines Highway   CVN, 2012/09/15
# 145      Damaged cabin, blocked Klawock Hollis Highway   ADN, 2014/01/16
# 146                          Blocked Coffman Cove Road   ADN, 2014/01/15
# 147                                Destroyed one house   ADN, 2014/01/16
# 155                  Blocked Nemo Loop Road, Mile 10.3  WRGS, 2014/08/07
# 156            Destroyed watershed restoration project   ADN, 2014/09/27
# 157                               Damaged water supply   ADN, 2014/09/30
# 158                       Disrupted power, closed road   KDN, 2014/10/14
# 164        Fatalities, destroyed houses, blocked roads   DSS, 2016/04/13
# 166                                Blocked parking lot    JE, 2015/09/30
# 167                                 Blocked Lutak Road   CVN, 2015/12/03
# 168                       Blocked Lutak Road at Mile 5   CVN, 2015/12/03
# 169                             Blocked Haines Highway   CVN, 2016/07/07
# 175                       Blocked Lutak Road at Mile 6   CVN, 2017/05/25
# 176                 Closed dock, diverted cruise ships   APM, 2017/09/05
# 177                 Closed dock, diverted cruise ships   APM, 2017/09/05
# 179                       Damaged houses, closed roads   DSS, 2017/09/14
# 180                                  Closed Thane Road    JE, 2017/10/27
# 181             Damaged Calhoun Avenue bridge abutment    JE, 2017/10/30
# 189               Impacted car, blocked Haines Highway   CVN, 2019/03/28
# 190                             Blocked Haines Highway   CVN, 2019/03/14
# 191                       Blocked Lutak Road at Mile 7   CVN, 2019/03/14
# 193                             Blocked Haines Highway  JADE, 2018/10/15
# 197         Blocked Thorne Bay Road, interrupted power   ADN, 2019/01/28
# 201                  Blocked Mitkof Highway at Mile 18   PPT, 2019/09/26
# 202                                 Blocked Thane Road    JE, 2019/10/07
